# %%
import pandas as pd
import gzip
import json
import ast

data_list = []
file_path = 'australian_users_items.json'
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            # Usar ast.literal_eval para convertir la línea en un diccionario
            json_data = ast.literal_eval(line)
            data_list.append(json_data)
        except ValueError as e:
            print(f"Error en la línea: {line}")
            continue
df_user_items = pd.DataFrame(data_list)

# Creo un df con el archivo review y accedo a la columna que me interesa desanidar.
df_items = df_user_items.explode('items')

# Creo un nuevo df donde esta la info desanidada en columnas
df_items = pd.concat([df_user_items.drop(['items'], axis=1), df_user_items['items'].apply(pd.Series)], axis=1) 

# Guardamos el dataframe obtenido con compresión parquet
df_items.to_parquet('../data/df_items.parquet')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/pc/Documentos/henry/Steam_games_PI_1/01_Preparacion/03_eda_user_reviews.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/home/pc/Documentos/henry/Steam_games_PI_1/01_Preparacion/03_eda_user_reviews.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/home/pc/Documentos/henry/Steam_games_PI_1/01_Preparacion/03_eda_user_reviews.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from funciones_aux.desempaqueta_users_items  import desempaquetado_users_items
#       <a href='vscode-notebook-cell:/home/pc/Documentos/henry/Steam_games_PI_1/01_Preparacion/03_eda_user_reviews.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> data_list = []
#       <a href='vscode-notebook-cell:/home/pc/Documentos/henry/Steam_games_PI_1/01_Preparacion/03_eda_user_reviews.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> file_path = 'australian_users_items.json'
#
# ModuleNotFoundError: No module named 'funciones_aux'

# %%
import pandas as pd

# %%
items_data = pd.read_csv('../data/raw/items.csv.gz',compression='gzip')

# %%
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url   item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10.0
# 1        http://steamcommunity.com/profiles/76561197970...      20.0
# 2        http://steamcommunity.com/profiles/76561197970...      30.0
# 3        http://steamcommunity.com/profiles/76561197970...      40.0
# 4        http://steamcommunity.com/profiles/76561197970...      50.0
# ...                                                    ...       ...
# 5170010  http://steamcommunity.com/profiles/76561198329...  373330.0
# 5170011  http://steamcommunity.com/profiles/76561198329...  388490.0
# 5170012  http://steamcommunity.com/profiles/76561198329...  521570.0
# 5170013  http://steamcommunity.com/profiles/76561198329...  519140.0
# 5170014     http://steamcommunity.com/id/edward_tremethick       NaN
#
#                              item_name  playtime_forever  playtime_2weeks
# 0                       Counter-Strike               6.0              0.0
# 1                Team Fortress Classic               0.0              0.0
# 2                        Day of Defeat               7.0              0.0
# 3                   Deathmatch Classic               0.0              0.0
# 4            Half-Life: Opposing Force               0.0              0.0
# ...                                ...               ...              ...
# 5170010                    All Is Dust               0.0              0.0
# 5170011  One Way To Die: Steam Edition               3.0              3.0
# 5170012          You Have 10 Seconds 2               4.0              4.0
# 5170013                     Minds Eyes               3.0              3.0
# 5170014                            NaN               NaN              NaN
#
# [5170015 rows x 8 columns]
